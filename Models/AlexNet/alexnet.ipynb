# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from IPython.display import HTML
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import numpy as np
import seaborn as sns

# %%
IMAGE_SIZE = 224
CHANNELS = 3
BATCH_SIZE = 32

# %%
original_train_dir = '/kaggle/input/fine-grained-fruit-quality-assessment/train/train'
orig_train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
)

orig_train_data = orig_train_datagen.flow_from_directory(
    original_train_dir,  # Point to the new writable directory
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)
# Out:
# Found 7395 images belonging to 7 classes.

# %%
# Get class labels and their corresponding indices
class_labels = list(orig_train_data.class_indices.keys())

# Count the number of samples per class
class_counts = np.bincount(orig_train_data.classes)

# Plot the class distribution
plt.figure(figsize=(10, 6))
sns.barplot(x=class_labels, y=class_counts)
plt.title('Class Distribution in Training Data')
plt.xlabel('Class')
plt.ylabel('Number of Samples')
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

base_dir = '/kaggle/input/fine-grained-fruit-quality-assessment/train/train'

classes_to_augment = ['tomato_half_ripened', 'tomato_green', 'tomato_fully_ripened']

num_augmented_images = 500

augmented_base_dir = '/kaggle/working/augmented_data'
os.makedirs(augmented_base_dir, exist_ok=True)

datagen_augment = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
for class_name in classes_to_augment:
    original_class_dir = os.path.join(base_dir, class_name)
    augmented_class_dir = os.path.join(augmented_base_dir, class_name)  
    os.makedirs(augmented_class_dir, exist_ok=True)

    image_files = [f for f in os.listdir(original_class_dir) if os.path.isfile(os.path.join(original_class_dir, f))]
    print(f"Found {len(image_files)} images in class: {class_name}")

    image_generator = datagen_augment.flow_from_directory(
        base_dir,
        classes=[class_name],
        target_size=(224, 224),
        batch_size=1,
        shuffle=True,
        save_to_dir=augmented_class_dir,  
        save_prefix='augmented',
        save_format='jpg'
    )

    num_generated = 0
    for _ in range(num_augmented_images):
        next(image_generator)
        num_generated += 1
    print(f"Generated {num_generated} augmented images for class: {class_name} in {augmented_class_dir}")

print("Augmentation process complete! Augmented images are saved in /kaggle/working/augmented_data/")
# Out:
# Found 90 images in class: tomato_half_ripened
# Found 90 images belonging to 1 classes.
# Generated 500 augmented images for class: tomato_half_ripened in /kaggle/working/augmented_data/tomato_half_ripened
# Found 371 images in class: tomato_green
# Found 371 images belonging to 1 classes.
# Generated 500 augmented images for class: tomato_green in /kaggle/working/augmented_data/tomato_green
# Found 55 images in class: tomato_fully_ripened
# Found 55 images belonging to 1 classes.
# Generated 500 augmented images for class: tomato_fully_ripened in /kaggle/working/augmented_data/tomato_fully_ripened
# Augmentation process complete! Augmented images are saved in /kaggle/working/augmented_data/

# %%
import shutil

original_train_dir = '/kaggle/input/fine-grained-fruit-quality-assessment/train/train'
writable_train_dir = '/kaggle/working/writable_train_data'
augmented_base_dir = '/kaggle/working/augmented_data'

if os.path.exists(writable_train_dir):
    shutil.rmtree(writable_train_dir)  
shutil.copytree(original_train_dir, writable_train_dir)
print(f"Original training data copied to {writable_train_dir}")

for class_name in classes_to_augment:
    src_dir = os.path.join(augmented_base_dir, class_name)
    dest_dir = os.path.join(writable_train_dir, class_name)
    for filename in os.listdir(src_dir):
        if filename.startswith('augmented'):
            src_file = os.path.join(src_dir, filename)
            dest_file = os.path.join(dest_dir, filename)
            shutil.move(src_file, dest_file)
    print(f"Moved augmented images for {class_name} to {dest_dir}")


print("ImageDataGenerators are now set up to use the training data with augmented images.")
# Out:
# Original training data copied to /kaggle/working/writable_train_data
# Moved augmented images for tomato_half_ripened to /kaggle/working/writable_train_data/tomato_half_ripened
# Moved augmented images for tomato_green to /kaggle/working/writable_train_data/tomato_green
# Moved augmented images for tomato_fully_ripened to /kaggle/working/writable_train_data/tomato_fully_ripened
# ImageDataGenerators are now set up to use the training data with augmented images.

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    validation_split=0.2
)

train_data = train_datagen.flow_from_directory(
    writable_train_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=42
)

val_data = train_datagen.flow_from_directory(
    writable_train_dir,  
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 7117 images belonging to 7 classes.
# Found 1778 images belonging to 7 classes.

# %%
class_labels = list(train_data.class_indices.keys())

class_counts = np.bincount(train_data.classes)

plt.figure(figsize=(10, 6))
sns.barplot(x=class_labels, y=class_counts)
plt.title('Class Distribution in Training Data')
plt.xlabel('Class')
plt.ylabel('Number of Samples')
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
import matplotlib.pyplot as plt
import numpy as np

num_classes = len(train_data.class_indices)
class_names = list(train_data.class_indices.keys())

samples_per_class = {}

while len(samples_per_class) < num_classes:
    images, labels = next(train_data)  
    for img, label in zip(images, labels):
        class_index = np.argmax(label)
        if class_index not in samples_per_class:
            samples_per_class[class_index] = img
        if len(samples_per_class) == num_classes:
            break

plt.figure(figsize=(15, 8))
for class_index, img in samples_per_class.items():
    ax = plt.subplot(1, num_classes, class_index + 1)
    plt.imshow(img)
    plt.title(class_names[class_index])
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
print(class_labels)
print(train_data.class_indices)
# Out:
# ['banana_overripe', 'banana_ripe', 'banana_rotten', 'banana_unripe', 'tomato_fully_ripened', 'tomato_green', 'tomato_half_ripened']
# {'banana_overripe': 0, 'banana_ripe': 1, 'banana_rotten': 2, 'banana_unripe': 3, 'tomato_fully_ripened': 4, 'tomato_green': 5, 'tomato_half_ripened': 6}

# %%
def calculate_class_weights_tf(labels):
    """
    Calculates class weights based on the frequency of each class in a TensorFlow tensor.

    Args:
        labels (tf.Tensor): 1D TensorFlow tensor of class labels (integer type).

    Returns:
        dict: A dictionary where keys are class labels (as Python integers) and
              values are their corresponding class weights (as Python floats).
              Returns an empty dict if input is invalid.
    """
    if not isinstance(labels, tf.Tensor):
        print("Error: Input 'labels' must be a TensorFlow tensor.")
        return {}  # Return an empty dictionary for error handling

    if labels.shape.ndims != 1:
        print("Error: Input 'labels' must be a 1D tensor.")
        return {}

    if labels.dtype not in [tf.int32, tf.int64]:
        print("Error: Input 'labels' must be an integer tensor (tf.int32 or tf.int64).")
        return {}

    unique_labels, _ = tf.unique(labels)
    num_samples = tf.cast(tf.shape(labels)[0], tf.float32)
    class_counts = tf.cast(tf.math.bincount(tf.cast(labels, dtype=tf.int32)), tf.float32)
    # Add epsilon for numerical stability
    class_weights_tensor = num_samples / (tf.cast(tf.shape(unique_labels)[0], tf.float32) * class_counts + tf.keras.backend.epsilon())

    # Create a dictionary mapping class labels to their weights
    class_weights_dict = {}
    for i, label in enumerate(unique_labels.numpy()):
        class_weights_dict[label] = class_weights_tensor[i].numpy()

    return class_weights_dict

# %%
y_train = train_data.classes
num_classes = train_data.num_classes
print(f"Number of classes: {num_classes}")
input_shape = train_data.image_shape

# Convert labels to TensorFlow tensor
y_train_tensor = tf.convert_to_tensor(y_train, dtype=tf.int32)


# 3. Calculate class weights
class_weights = calculate_class_weights_tf(y_train_tensor)

print("Class labels:", np.unique(y_train))
print("Calculated class weights:", class_weights)
# Out:
# Number of classes: 7
# Class labels: [0 1 2 3 4 5 6]
# Calculated class weights: {0: 0.81993085, 1: 0.794308, 2: 0.5757159, 3: 0.8347408, 4: 2.289897, 5: 1.4587005, 6: 2.1540556}
# I0000 00:00:1747434956.014209      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1747434956.015027      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
from tensorflow.keras import layers, Model

def create_alexnet_model(input_shape, num_classes):
    # Input layer
    inputs = layers.Input(shape=input_shape)

    # First convolutional layer
    conv1 = layers.Conv2D(96, (11, 11), strides=(4, 4), activation='relu', padding='valid')(inputs)
    pool1 = layers.MaxPooling2D((3, 3), strides=(2, 2))(conv1)

    # Second convolutional layer
    conv2 = layers.Conv2D(256, (5, 5), activation='relu', padding='same')(pool1)
    pool2 = layers.MaxPooling2D((3, 3), strides=(2, 2))(conv2)

    # Third convolutional layer
    conv3 = layers.Conv2D(384, (3, 3), activation='relu', padding='same')(pool2)

    # Fourth convolutional layer
    conv4 = layers.Conv2D(384, (3, 3), activation='relu', padding='same')(conv3)

    # Fifth convolutional layer
    conv5 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool5 = layers.MaxPooling2D((3, 3), strides=(2, 2))(conv5)

    # Flatten the output
    flatten = layers.Flatten()(pool5)

    # First fully connected layer
    fc1 = layers.Dense(4096, activation='relu')(flatten)
    dropout1 = layers.Dropout(0.5)(fc1)

    # Second fully connected layer
    fc2 = layers.Dense(4096, activation='relu')(dropout1)
    dropout2 = layers.Dropout(0.5)(fc2)

    # Output layer
    outputs = layers.Dense(num_classes, activation='softmax')(dropout2)

    # Create model
    model = Model(inputs, outputs)
    return model

IMAGE_SIZE = 224
CHANNELS = 3

alexnet_model = create_alexnet_model(
    input_shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS),
    num_classes=7
)

alexnet_model.compile(
    optimizer='adamW',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

alexnet_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 54, 54, 96)          │          34,944 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 26, 26, 96)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 26, 26, 256)         │         614,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 12, 12, 384)         │         885,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 12, 12, 384)         │       1,327,488 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 12, 12, 256)         │         884,992 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 5, 5, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 6400)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 4096)                │      26,218,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4096)                │      16,781,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 7)                   │          28,679 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 46,775,687 (178.44 MB)
#  Trainable params: 46,775,687 (178.44 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow as tf
from tensorflow.keras import layers
import math
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=6,
    restore_best_weights=True,
    verbose=1)

reduce_lr = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=3,
    min_lr=1e-6,
    verbose=1)

checkpoint_filepath = '/kaggle/working/alexnet_model.keras'

checkpoint = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1)

callbacks = [early_stopping, reduce_lr, checkpoint]

history = alexnet_model.fit(
    train_data,
    validation_data=val_data,
    epochs=30, 
    callbacks=callbacks,
    verbose=1
)
loss, accuracy = alexnet_model.evaluatval_losse(val_data)
print(f"Validation Accuracy: {accuracy * 100:.2f}%")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747434963.817331     140 service.cc:148] XLA service 0x7f9704010760 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747434963.818525     140 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1747434963.818554     140 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1747434964.336354     140 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   2/223 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - accuracy: 0.1953 - loss: 5.8450
# I0000 00:00:1747434970.775284     140 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.2514 - loss: 2.0956
# Epoch 1: val_accuracy improved from -inf to 0.43138, saving model to /kaggle/working/alexnet_model.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 178s 748ms/step - accuracy: 0.2516 - loss: 2.0938 - val_accuracy: 0.4314 - val_loss: 1.2745 - learning_rate: 0.0010
# Epoch 2/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.4149 - loss: 1.2971
# Epoch 2: val_accuracy improved from 0.43138 to 0.56805, saving model to /kaggle/working/alexnet_model.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 159s 714ms/step - accuracy: 0.4151 - loss: 1.2968 - val_accuracy: 0.5681 - val_loss: 0.9714 - learning_rate: 0.0010
# Epoch 3/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.6084 - loss: 0.9190
# Epoch 3: val_accuracy improved from 0.56805 to 0.68166, saving model to /kaggle/working/alexnet_model.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 158s 707ms/step - accuracy: 0.6086 - loss: 0.9186 - val_accuracy: 0.6817 - val_loss: 0.7593 - learning_rate: 0.0010
# Epoch 4/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.7345 - loss: 0.6644
# Epoch 4: val_accuracy improved from 0.68166 to 0.74859, saving model to /kaggle/working/alexnet_model.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 158s 708ms/step - accuracy: 0.7345 - loss: 0.6643 - val_accuracy: 0.7486 - val_loss: 0.6733 - learning_rate: 0.0010
# Epoch 5/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.7607 - loss: 0.5816
# Epoch 5: val_accuracy improved from 0.74859 to 0.76884, saving model to /kaggle/working/alexnet_model.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 158s 708ms/step - accuracy: 0.7607 - loss: 0.5817 - val_accuracy: 0.7688 - val_loss: 0.5745 - learning_rate: 0.0010
# Epoch 6/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.7742 - loss: 0.5868
# Epoch 6: val_accuracy improved from 0.76884 to 0.82565, saving model to /kaggle/working/alexnet_model.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 158s 711ms/step - accuracy: 0.7743 - loss: 0.5867 - val_accuracy: 0.8256 - val_loss: 0.4440 - learning_rate: 0.0010
# Epoch 7/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.8043 - loss: 0.4963
# Epoch 7: val_accuracy did not improve from 0.82565
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 153s 687ms/step - accuracy: 0.8043 - loss: 0.4963 - val_accuracy: 0.8223 - val_loss: 0.4599 - learning_rate: 0.0010
# Epoch 8/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.8063 - loss: 0.4984
# Epoch 8: val_accuracy did not improve from 0.82565
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 154s 688ms/step - accuracy: 0.8063 - loss: 0.4984 - val_accuracy: 0.8189 - val_loss: 0.4645 - learning_rate: 0.0010
# Epoch 9/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.8124 - loss: 0.4725
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 9: val_accuracy did not improve from 0.82565
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 156s 698ms/step - accuracy: 0.8125 - loss: 0.4725 - val_accuracy: 0.8183 - val_loss: 0.4465 - learning_rate: 0.0010
# Epoch 10/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.8428 - loss: 0.4049
# Epoch 10: val_accuracy improved from 0.82565 to 0.87402, saving model to /kaggle/working/alexnet_model.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 157s 705ms/step - accuracy: 0.8428 - loss: 0.4048 - val_accuracy: 0.8740 - val_loss: 0.3306 - learning_rate: 5.0000e-04
# Epoch 11/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.8594 - loss: 0.3756
# Epoch 11: val_accuracy did not improve from 0.87402
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 155s 695ms/step - accuracy: 0.8594 - loss: 0.3757 - val_accuracy: 0.8639 - val_loss: 0.3647 - learning_rate: 5.0000e-04
# Epoch 12/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.8658 - loss: 0.3594
# Epoch 12: val_accuracy did not improve from 0.87402
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 156s 699ms/step - accuracy: 0.8657 - loss: 0.3594 - val_accuracy: 0.8470 - val_loss: 0.3916 - learning_rate: 5.0000e-04
# Epoch 13/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.8573 - loss: 0.3618
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 13: val_accuracy did not improve from 0.87402
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 153s 687ms/step - accuracy: 0.8573 - loss: 0.3617 - val_accuracy: 0.8706 - val_loss: 0.3345 - learning_rate: 5.0000e-04
# Epoch 14/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.8763 - loss: 0.3038
# Epoch 14: val_accuracy improved from 0.87402 to 0.87458, saving model to /kaggle/working/alexnet_model.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 160s 718ms/step - accuracy: 0.8763 - loss: 0.3039 - val_accuracy: 0.8746 - val_loss: 0.3178 - learning_rate: 2.5000e-04
# Epoch 15/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.8820 - loss: 0.2980
# Epoch 15: val_accuracy improved from 0.87458 to 0.88526, saving model to /kaggle/working/alexnet_model.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 156s 701ms/step - accuracy: 0.8820 - loss: 0.2980 - val_accuracy: 0.8853 - val_loss: 0.2943 - learning_rate: 2.5000e-04
# Epoch 16/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.8794 - loss: 0.3067
# Epoch 16: val_accuracy did not improve from 0.88526
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 155s 694ms/step - accuracy: 0.8794 - loss: 0.3067 - val_accuracy: 0.8757 - val_loss: 0.3367 - learning_rate: 2.5000e-04
# Epoch 17/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.8804 - loss: 0.3066
# Epoch 17: val_accuracy did not improve from 0.88526
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 157s 706ms/step - accuracy: 0.8804 - loss: 0.3066 - val_accuracy: 0.8645 - val_loss: 0.3568 - learning_rate: 2.5000e-04
# Epoch 18/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.8791 - loss: 0.3112
# Epoch 18: val_accuracy improved from 0.88526 to 0.88583, saving model to /kaggle/working/alexnet_model.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 157s 707ms/step - accuracy: 0.8792 - loss: 0.3111 - val_accuracy: 0.8858 - val_loss: 0.2879 - learning_rate: 2.5000e-04
# Epoch 19/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.8783 - loss: 0.2995
# Epoch 19: val_accuracy did not improve from 0.88583
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 150s 675ms/step - accuracy: 0.8783 - loss: 0.2994 - val_accuracy: 0.8774 - val_loss: 0.3031 - learning_rate: 2.5000e-04
# Epoch 20/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.9006 - loss: 0.2639
# Epoch 20: val_accuracy did not improve from 0.88583
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 160s 718ms/step - accuracy: 0.9006 - loss: 0.2639 - val_accuracy: 0.8819 - val_loss: 0.2799 - learning_rate: 2.5000e-04
# Epoch 21/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.8966 - loss: 0.2642
# Epoch 21: val_accuracy improved from 0.88583 to 0.89033, saving model to /kaggle/working/alexnet_model.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 159s 715ms/step - accuracy: 0.8966 - loss: 0.2643 - val_accuracy: 0.8903 - val_loss: 0.2967 - learning_rate: 2.5000e-04
# Epoch 22/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.8988 - loss: 0.2639
# Epoch 22: val_accuracy improved from 0.89033 to 0.89201, saving model to /kaggle/working/alexnet_model.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 152s 679ms/step - accuracy: 0.8988 - loss: 0.2639 - val_accuracy: 0.8920 - val_loss: 0.2737 - learning_rate: 2.5000e-04
# Epoch 23/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.9041 - loss: 0.2469
# Epoch 23: val_accuracy did not improve from 0.89201
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 150s 674ms/step - accuracy: 0.9041 - loss: 0.2469 - val_accuracy: 0.8864 - val_loss: 0.2848 - learning_rate: 2.5000e-04
# Epoch 24/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.9027 - loss: 0.2436
# Epoch 24: val_accuracy improved from 0.89201 to 0.89764, saving model to /kaggle/working/alexnet_model.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 158s 710ms/step - accuracy: 0.9027 - loss: 0.2437 - val_accuracy: 0.8976 - val_loss: 0.2694 - learning_rate: 2.5000e-04
# Epoch 25/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.9052 - loss: 0.2395
# Epoch 25: val_accuracy did not improve from 0.89764
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 155s 695ms/step - accuracy: 0.9052 - loss: 0.2395 - val_accuracy: 0.8960 - val_loss: 0.2886 - learning_rate: 2.5000e-04
# Epoch 26/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.9128 - loss: 0.2266
# Epoch 26: val_accuracy did not improve from 0.89764
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 155s 695ms/step - accuracy: 0.9128 - loss: 0.2266 - val_accuracy: 0.8960 - val_loss: 0.2720 - learning_rate: 2.5000e-04
# Epoch 27/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.9187 - loss: 0.2177
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 27: val_accuracy did not improve from 0.89764
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 154s 690ms/step - accuracy: 0.9187 - loss: 0.2178 - val_accuracy: 0.8971 - val_loss: 0.2594 - learning_rate: 2.5000e-04
# Epoch 28/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.9271 - loss: 0.1964
# Epoch 28: val_accuracy improved from 0.89764 to 0.91001, saving model to /kaggle/working/alexnet_model.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 156s 699ms/step - accuracy: 0.9270 - loss: 0.1964 - val_accuracy: 0.9100 - val_loss: 0.2571 - learning_rate: 1.2500e-04
# Epoch 29/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.9285 - loss: 0.1856
# Epoch 29: val_accuracy improved from 0.91001 to 0.91226, saving model to /kaggle/working/alexnet_model.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 157s 705ms/step - accuracy: 0.9285 - loss: 0.1856 - val_accuracy: 0.9123 - val_loss: 0.2338 - learning_rate: 1.2500e-04
# Epoch 30/30
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.9204 - loss: 0.1961
# Epoch 30: val_accuracy improved from 0.91226 to 0.91282, saving model to /kaggle/working/alexnet_model.keras
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 163s 732ms/step - accuracy: 0.9204 - loss: 0.1960 - val_accuracy: 0.9128 - val_loss: 0.2434 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 30.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_35/626316353.py in <cell line: 0>()
#      37     verbose=1
#      38 )
# ---> 39 loss, accuracy = alexnet_model.evaluatval_losse(val_data)
#      40 print(f"Validation Accuracy: {accuracy * 100:.2f}%")
#
# AttributeError: 'Functional' object has no attribute 'evaluatval_losse'

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

val_preds = np.argmax(alexnet_model.predict(val_data), axis=1)
val_labels = val_data.classes
print(classification_report(val_labels, val_preds, target_names=list(val_data.class_indices.keys())))
# Out:
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 53s 937ms/step
#                       precision    recall  f1-score   support
#
#      banana_overripe       0.96      0.91      0.93       310
#          banana_ripe       0.91      0.97      0.94       320
#        banana_rotten       0.97      0.95      0.96       441
#        banana_unripe       0.98      0.99      0.99       304
# tomato_fully_ripened       0.77      0.80      0.79       111
#         tomato_green       0.86      0.76      0.80       174
#  tomato_half_ripened       0.66      0.75      0.70       118
#
#             accuracy                           0.91      1778
#            macro avg       0.87      0.87      0.87      1778
#         weighted avg       0.91      0.91      0.91      1778

# %%
cm = confusion_matrix(val_labels, val_preds)
class_names = val_data.class_indices.keys()
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
# Out:
# Text(50.58159722222221, 0.5, 'True Labels')

# %%
import pandas as pd
import numpy as np
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator


# Define the class label mapping (for converting numerical predictions to the required indices)
class_mapping = {
    'banana_overripe': 0,
    'banana_ripe': 1,
    'banana_rotten': 2,
    'banana_unripe': 3,
    'tomato_fully_ripened': 4,
    'tomato_green': 5,
    'tomato_half_ripened': 6
}

reverse_class_mapping = {v: k for k, v in class_mapping.items()}


test_data_gen = ImageDataGenerator(    
    rescale=1./255,
    rotation_range=40,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest')


test_image_files = sorted([f for f in os.listdir('/kaggle/input/fine-grained-fruit-quality-assessment/test/testNew') if os.path.isfile(os.path.join('/kaggle/input/fine-grained-fruit-quality-assessment/test/testNew', f))])


test_data = test_data_gen.flow_from_dataframe(
    pd.DataFrame({'filename': test_image_files}),
    directory='/kaggle/input/fine-grained-fruit-quality-assessment/test/testNew',
    x_col='filename',
    target_size=(224, 224),
    batch_size=BATCH_SIZE,
    class_mode=None,  # No labels for test data
    shuffle=False
)

test_preds = alexnet_model.predict(test_data)

predicted_classes = np.argmax(test_preds, axis=1)


image_ids = test_image_files


submission_df = pd.DataFrame({'ImageID': image_ids, 'Class': predicted_classes})


submission_df.to_csv('/kaggle/working/alexnet_model.csv', index=False)

print("Submission file 'submission.csv' has been created successfully!")
# Out:
# Found 2484 validated image filenames.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 59s 748ms/step
# Submission file 'submission.csv' has been created successfully!

# %%
submission_df.to_csv('/kaggle/working/alexnet_model.csv', index=False)

# %%
alexnet_model.save('/kaggle/working/alexnet_model.keras')

# %%
alexnet_model.save_weights('/kaggle/working/alexnet_model.weights.h5')
